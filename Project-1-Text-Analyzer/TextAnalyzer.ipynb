# %%
pip install textblob nltk
# Out:
# Requirement already satisfied: textblob in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\priyanka\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Priyanka\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Priyanka\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Priyanka\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
from collections import Counter
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords',quiet=True)
nltk.download('punkt',quiet=True)
# Out:
# True

# %%
class TextAnalyzer:
    def __init__(self, text):
        self.text = text
        self.blob = TextBlob(text)
    def get_word_count(self):
        words = self.text.split()
        return len(words)
    def get_sentiment(self):
        score = self.blob.sentiment.polarity
        if score > 0:
            return "Positive"
        elif score < 0:
            return "Negative"
        else:
            return "Neutral"
    def get_keywords(self):
        cleaned_text = re.sub(r'[^\w\s]', '', self.text).lower()
        words = cleaned_text.split()
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word not in stop_words]
        return Counter(filtered_words).most_common(3)
user_input = input("Enter text: ")
analyzer = TextAnalyzer(user_input)
print("Word Count:", analyzer.get_word_count())
print("Sentiment:", analyzer.get_sentiment())
print("Top Keywords:", analyzer.get_keywords())
